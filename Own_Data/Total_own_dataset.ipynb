# %%
import pandas as pd
import os

dirOnTable = "/Users/maudvdberg/ML4QS/onTable"

os.chdir(dirOnTable)
Acc_onTable = pd.read_csv("Accelerometer.csv")
Gyro_onTable = pd.read_csv("Gyroscope.csv")
Mag_onTable = pd.read_csv("Magnetometer.csv")
Acc_onTable["Time (s)"] = range(1, len(Acc_onTable) + 1)
Gyro_onTable["Time (s)"] = range(1, len(Acc_onTable) + 1)
Mag_onTable["Time (s)"] = range(1, len(Acc_onTable) + 1)
df_onTable = pd.merge(Acc_onTable, Gyro_onTable, on = 'Time (s)')
df_onTable2 = pd.merge(df_onTable, Mag_onTable, on = 'Time (s)')

# %%
df_onTable2
# Out:
#       Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# 0            1                0.011971               -0.114922
# 1            2                0.033519               -0.117316
# 2            3                0.026336               -0.126893
# 3            4                0.019154               -0.114922
# 4            5                0.033519               -0.124498
# ...        ...                     ...                     ...
# 1189      1190                0.026336               -0.119710
# 1190      1191                0.028730               -0.112527
# 1191      1192                0.019154               -0.107739
# 1192      1193                0.021548               -0.117316
# 1193      1194                0.021548               -0.112527
#
#       Acceleration z (m/s^2)  Gyroscope x (rad/s)  Gyroscope y (rad/s)  \
# 0                   9.612720            -0.002131             0.000000
# 1                   9.607931             0.000533            -0.001065
# 2                   9.615114            -0.002131            -0.001065
# 3                   9.595961             0.000533             0.001065
# 4                   9.612720             0.000000             0.001065
# ...                      ...                  ...                  ...
# 1189                9.610326            -0.001598            -0.000533
# 1190                9.617508             0.000533             0.000000
# 1191                9.612720            -0.001065             0.000533
# 1192                9.605537             0.000000            -0.001598
# 1193                9.610326            -0.000533             0.000533
#
#       Gyroscope z (rad/s)  Magnetic field x (µT)  Magnetic field y (µT)  \
# 0               -0.004794              22.020000              31.379999
# 1               -0.001598              21.660000              32.340000
# 2               -0.002131              21.420000              32.099998
# 3               -0.000533              21.480000              32.639999
# 4               -0.000533              21.660000              31.439999
# ...                   ...                    ...                    ...
# 1189             0.001598              21.840000              32.279999
# 1190             0.000000              21.779999              31.619999
# 1191             0.001598              21.180000              32.399998
# 1192             0.001598              21.539999              31.619999
# 1193             0.000533              21.600000              32.340000
#
#       Magnetic field z (µT)
# 0                -59.699997
# 1                -60.480000
# 2                -61.020000
# 3                -60.239998
# 4                -60.059998
# ...                     ...
# 1189             -60.539997
# 1190             -60.180000
# 1191             -59.879997
# 1192             -59.099998
# 1193             -61.020000
#
# [1194 rows x 10 columns]

# %%
dirSit = "/Users/maudvdberg/ML4QS/Sitting"

os.chdir(dirSit)
Acc_Sit = pd.read_csv("Accelerometer.csv")
Gyro_Sit = pd.read_csv("Gyroscope.csv")
#Mag_Sit = pd.read_csv("Magnetometer.csv")
Acc_Sit["Time (s)"] = range(1195, (len(Acc_Sit) + 1195))
Gyro_Sit["Time (s)"] = range(1195, (len(Gyro_Sit) + 1195))
#Mag_Sit["Time (s)"] = range(1195, (len(Mag_Sit) + 1196))
df_Sit = pd.merge(Acc_Sit, Gyro_Sit, on = 'Time (s)')
#df_Sit = pd.merge(df_Sit, Mag_Sit, on = 'Time (s)')

dirWalk = "/Users/maudvdberg/ML4QS/Walking"
os.chdir(dirWalk)
Acc_Walk = pd.read_csv("Accelerometer.csv")
Gyro_Walk = pd.read_csv("Gyroscope.csv")
#Mag_Walk = pd.read_csv("Magnetometer.csv")
Acc_Walk["Time (s)"] = range(2392, (len(Acc_Walk) + 2392))
Gyro_Walk["Time (s)"] = range(2392, (len(Gyro_Walk) + 2392))
#Mag_Walk["Time (s)"] = range(2392, (len(Mag_Walk) + 2392))
df_Walk = pd.merge(Acc_Walk, Gyro_Walk, on = 'Time (s)')
#df_Walk = pd.merge(df_Walk, Mag_Walk, on = 'Time (s)')


dirRun = "/Users/maudvdberg/ML4QS/Running" 
os.chdir(dirRun)
Acc_Run = pd.read_csv("Accelerometer.csv")
Gyro_Run = pd.read_csv("Gyroscope.csv")
#Mag_Run = pd.read_csv("Magnetometer.csv")
Acc_Run["Time (s)"] = range(3590, (len(Acc_Run) + 3590))
Gyro_Run["Time (s)"] = range(3590, (len(Gyro_Run) + 3590))
#Mag_Run["Time (s)"] = range(3590, (len(Mag_Run) + 3590))
df_Run = pd.merge(Acc_Run, Gyro_Run, on = 'Time (s)')
#df_Run = pd.merge(df_Run, Mag_Run, on = 'Time (s)')
frames = [df_onTable, df_Sit, df_Walk, df_Run]
df_all = pd.concat(frames)

# %%
df_all
# Out:
#       Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# 0            1                0.011971               -0.114922
# 1            2                0.033519               -0.117316
# 2            3                0.026336               -0.126893
# 3            4                0.019154               -0.114922
# 4            5                0.033519               -0.124498
# ...        ...                     ...                     ...
# 1190      4780               26.714502               20.757729
# 1191      4781                5.425261               16.201563
# 1192      4782                2.221819               -3.093309
# 1193      4783               24.028208                6.440403
# 1194      4784               -5.547365               10.230424
#
#       Acceleration z (m/s^2)  Gyroscope x (rad/s)  Gyroscope y (rad/s)  \
# 0                   9.612720            -0.002131             0.000000
# 1                   9.607931             0.000533            -0.001065
# 2                   9.615114            -0.002131            -0.001065
# 3                   9.595961             0.000533             0.001065
# 4                   9.612720             0.000000             0.001065
# ...                      ...                  ...                  ...
# 1190                4.383783            -1.443433            -0.201335
# 1191                5.353435             0.841026             0.635963
# 1192               -0.351948             0.937433             0.691889
# 1193                3.423708            -4.041614            -1.280980
# 1194                8.173804            -0.116114            -0.201868
#
#       Gyroscope z (rad/s)
# 0               -0.004794
# 1               -0.001598
# 2               -0.002131
# 3               -0.000533
# 4               -0.000533
# ...                   ...
# 1190             1.689509
# 1191            -2.495382
# 1192             0.117712
# 1193             2.833071
# 1194            -0.164583
#
# [4784 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(2)
fig.suptitle('Vertically stacked subplots')
axs[0].plot(df_Run["Time (s)"], df_Run["Acceleration x (m/s^2)"])
axs[1].plot(df_Walk["Time (s)"], df_Walk["Acceleration x (m/s^2)"])
