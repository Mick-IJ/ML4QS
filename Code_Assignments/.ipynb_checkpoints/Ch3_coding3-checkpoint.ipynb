# %%
import pandas as pd
import numpy as np
import gc
import time
from contextlib import contextmanager
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_squared_error as mse
from sklearn.model_selection import KFold, StratifiedKFold
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook as tqdm
from sklearn.model_selection import train_test_split as tts
# %matplotlib inline

# %%
df = pd.read_csv(r'../Python3Code/intermediate_datafiles/chapter2_result.csv')

cols = ['acc_phone_x', 'acc_phone_y', 'acc_phone_z',
       'acc_watch_x', 'acc_watch_y', 'acc_watch_z', 'gyr_phone_x',
       'gyr_phone_y', 'gyr_phone_z', 'gyr_watch_x', 'gyr_watch_y',
       'gyr_watch_z', 'hr_watch_rate',
       'light_phone_lux', 'mag_phone_x', 'mag_phone_y', 'mag_phone_z', 
        'mag_watch_x', 'mag_watch_y', 'mag_watch_z', 'press_phone_pressure']

df = df[cols]

# %%
for column in df.columns:
    df.loc[(df[column] > (df[column].mean() + 4*df[column].std())), column] = np.nan
    df.loc[(df[column] < (df[column].mean() - 4*df[column].std())), column] = np.nan

# %% [markdown]
# # FEATURES

# %%
df.loc[:, 'last_hr_watch_rate'] = df['hr_watch_rate'].shift(1).fillna(method='ffill')

# %% [markdown]
# # BASELINE

# %%
heartrate = df[df['hr_watch_rate'].notnull()]['hr_watch_rate']
baseline_pred = np.repeat(heartrate.mean(), len(heartrate))
print('Baseline RMSE:', round(np.sqrt(mse(heartrate, baseline_pred)), 3))
# Out:
# Baseline RMSE: 35.23

# %%
plt.plot(df['hr_watch_rate'].fillna(heartrate.mean()))

# %% [markdown]
# # INTERPOLATION

# %%
plt.plot(df['hr_watch_rate'].interpolate())

# %% [markdown]
# # MODEL

# %%
def kfold_lightgbm(df, num_folds, stratified = False, debug= False, seed = 1001):
    # Divide in training/validation and test data
    train_df = df[df['hr_watch_rate'].notnull()]
    test_df = df[df['hr_watch_rate'].isnull()]
        
    print("Starting LightGBM. Train shape: {}, test shape: {}".format(train_df.shape, test_df.shape))
    del df
    # Cross validation model
    if stratified:
        folds = StratifiedKFold(n_splits= num_folds, shuffle=True, random_state=seed)
    else:
        folds = KFold(n_splits= num_folds, shuffle=True, random_state=seed)
    # Create arrays and dataframes to store results
    oof_preds = np.zeros(train_df.shape[0])
    sub_preds = np.zeros(test_df.shape[0])
    feature_importance_split_df = pd.DataFrame()
    feature_importance_gain_df = pd.DataFrame()
    fold_prediction = test_df.copy()

    feats = [f for f in train_df.columns if f not in ['hr_watch_rate']]
    
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[feats], train_df['hr_watch_rate'])):
        train_x, train_y = train_df[feats].iloc[train_idx], train_df['hr_watch_rate'].iloc[train_idx]
        valid_x, valid_y = train_df[feats].iloc[valid_idx], train_df['hr_watch_rate'].iloc[valid_idx]

        # LightGBM parameters found by Bayesian optimization
        clf = LGBMRegressor(
            metric = 'rmse',
            nthread=-1,
            n_estimators=100000,
            learning_rate=0.06,
            num_leaves=10,
            colsample_bytree=.6,
            subsample=0.6,
            max_depth=3,
            reg_alpha=.7,
            reg_lambda=.9,
            min_child_samples = 1200,
            min_child_weight = 60,
            min_data_per_group = 1200,
            min_data_in_bin = 300,
            silent=-1,
            verbose=-1)

        clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], 
            eval_metric= 'rmse', verbose= 100, early_stopping_rounds= 200)
        
        oof_preds[valid_idx] = clf.predict(valid_x, num_iteration=clf.best_iteration_)
        
        test_pred =  clf.predict(test_df[feats], num_iteration=clf.best_iteration_)
        sub_preds += test_pred / folds.n_splits
        
        fold_prediction.loc[:, str(seed) + '_fold_' + str(n_fold)] = test_pred

        fold_importance_df = pd.DataFrame()
        fold_importance_df["feature"] = feats
        fold_importance_df["importance"] = clf.booster_.feature_importance(importance_type = 'split')
        fold_importance_df["fold"] = n_fold + 1
        feature_importance_split_df = pd.concat([feature_importance_split_df, fold_importance_df], axis=0)
        
        fold_importance_df2 = pd.DataFrame()
        fold_importance_df2["feature"] = feats
        fold_importance_df2["importance"] = clf.booster_.feature_importance(importance_type = 'gain')
        fold_importance_df2["fold"] = n_fold + 1
        feature_importance_gain_df = pd.concat([feature_importance_gain_df, fold_importance_df2], axis=0)        
        
        print('Fold %2d RMSE : %.6f' % (n_fold + 1, np.sqrt(mse(valid_y, oof_preds[valid_idx]))))
        print()
        del clf, train_x, train_y, valid_x, valid_y

    print('Full RMSE score %.6f' % np.sqrt(mse(train_df['hr_watch_rate'], oof_preds)))
 
    display_importances(feature_importance_split_df)
    display_importances(feature_importance_gain_df)
    return feature_importance_split_df, feature_importance_gain_df, fold_prediction

# Display/plot feature importance
def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", 
                                                                                                   ascending=False)[:40].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    plt.figure(figsize=(8, 10))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()

# %%
split, gain, pred = kfold_lightgbm(df, 5)
# Out:
# Starting LightGBM. Train shape: (7511, 22), test shape: (24327, 22)
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 5.87409	valid_1's rmse: 5.96025
# [200]	training's rmse: 5.05889	valid_1's rmse: 5.28722
# [300]	training's rmse: 4.88945	valid_1's rmse: 5.18019
# [400]	training's rmse: 4.79821	valid_1's rmse: 5.12542
# [500]	training's rmse: 4.73811	valid_1's rmse: 5.08611
# [600]	training's rmse: 4.69	valid_1's rmse: 5.04872
# [700]	training's rmse: 4.65012	valid_1's rmse: 5.02578
# [800]	training's rmse: 4.61823	valid_1's rmse: 5.01452
# [900]	training's rmse: 4.58868	valid_1's rmse: 5.00438
# [1000]	training's rmse: 4.56151	valid_1's rmse: 4.99361
# [1100]	training's rmse: 4.53845	valid_1's rmse: 4.98207
# [1200]	training's rmse: 4.51702	valid_1's rmse: 4.97626
# [1300]	training's rmse: 4.49735	valid_1's rmse: 4.9692
# [1400]	training's rmse: 4.47893	valid_1's rmse: 4.96074
# [1500]	training's rmse: 4.46119	valid_1's rmse: 4.95347
# [1600]	training's rmse: 4.44477	valid_1's rmse: 4.9496
# [1700]	training's rmse: 4.42808	valid_1's rmse: 4.94402
# [1800]	training's rmse: 4.4128	valid_1's rmse: 4.93996
# [1900]	training's rmse: 4.3979	valid_1's rmse: 4.93517
# [2000]	training's rmse: 4.38384	valid_1's rmse: 4.93073
# [2100]	training's rmse: 4.37138	valid_1's rmse: 4.92701
# [2200]	training's rmse: 4.35729	valid_1's rmse: 4.92615
# [2300]	training's rmse: 4.34435	valid_1's rmse: 4.92286
# [5800]	training's rmse: 4.08734	valid_1's rmse: 4.57938
# [5900]	training's rmse: 4.08149	valid_1's rmse: 4.57762
# [6000]	training's rmse: 4.0756	valid_1's rmse: 4.57802
# [6100]	training's rmse: 4.07004	valid_1's rmse: 4.57522
# [6200]	training's rmse: 4.06447	valid_1's rmse: 4.57356
# [6300]	training's rmse: 4.05788	valid_1's rmse: 4.57178
# [6400]	training's rmse: 4.05197	valid_1's rmse: 4.56912
# [6500]	training's rmse: 4.04568	valid_1's rmse: 4.56859
# [6600]	training's rmse: 4.03941	valid_1's rmse: 4.56783
# [6700]	training's rmse: 4.03438	valid_1's rmse: 4.56657
# [6800]	training's rmse: 4.02905	valid_1's rmse: 4.56627
# [6900]	training's rmse: 4.02422	valid_1's rmse: 4.5662
# [7000]	training's rmse: 4.01841	valid_1's rmse: 4.56512
# [7100]	training's rmse: 4.01301	valid_1's rmse: 4.56382
# [7200]	training's rmse: 4.00759	valid_1's rmse: 4.56317
# [7300]	training's rmse: 4.00256	valid_1's rmse: 4.56227
# [7400]	training's rmse: 3.99764	valid_1's rmse: 4.56204
# [7500]	training's rmse: 3.99228	valid_1's rmse: 4.56085
# [7600]	training's rmse: 3.98653	valid_1's rmse: 4.5595
# [7700]	training's rmse: 3.98156	valid_1's rmse: 4.56016
# [7800]	training's rmse: 3.97588	valid_1's rmse: 4.55867
# [7900]	training's rmse: 3.97066	valid_1's rmse: 4.55644
# [8000]	training's rmse: 3.96537	valid_1's rmse: 4.5548
# [8100]	training's rmse: 3.9604	valid_1's rmse: 4.55469
# [8200]	training's rmse: 3.9556	valid_1's rmse: 4.5533
# [8300]	training's rmse: 3.95069	valid_1's rmse: 4.55033
# [8400]	training's rmse: 3.94609	valid_1's rmse: 4.54895
# [8500]	training's rmse: 3.94142	valid_1's rmse: 4.54771
# [8600]	training's rmse: 3.93739	valid_1's rmse: 4.54712
# [8700]	training's rmse: 3.9335	valid_1's rmse: 4.54597
# [8800]	training's rmse: 3.92947	valid_1's rmse: 4.54455
# [8900]	training's rmse: 3.92616	valid_1's rmse: 4.5428
# [9000]	training's rmse: 3.92258	valid_1's rmse: 4.54268
# [9100]	training's rmse: 3.9184	valid_1's rmse: 4.54148
# [9200]	training's rmse: 3.91361	valid_1's rmse: 4.5396
# [9300]	training's rmse: 3.90988	valid_1's rmse: 4.53959
# [9400]	training's rmse: 3.90516	valid_1's rmse: 4.53829
# [9500]	training's rmse: 3.90015	valid_1's rmse: 4.53763
# [9600]	training's rmse: 3.89541	valid_1's rmse: 4.53529
# [9700]	training's rmse: 3.89123	valid_1's rmse: 4.53272
# [9800]	training's rmse: 3.88741	valid_1's rmse: 4.53392
# [9900]	training's rmse: 3.88324	valid_1's rmse: 4.53293
# [10000]	training's rmse: 3.87875	valid_1's rmse: 4.53184
# [10100]	training's rmse: 3.87444	valid_1's rmse: 4.53076
# [10200]	training's rmse: 3.87043	valid_1's rmse: 4.53024
# [10300]	training's rmse: 3.86692	valid_1's rmse: 4.52878
# [10400]	training's rmse: 3.86343	valid_1's rmse: 4.52956
# [2200]	training's rmse: 4.38431	valid_1's rmse: 4.92751
# [2300]	training's rmse: 4.37259	valid_1's rmse: 4.9237
# [2400]	training's rmse: 4.3601	valid_1's rmse: 4.91905
# [2500]	training's rmse: 4.34773	valid_1's rmse: 4.91523
# [2600]	training's rmse: 4.33665	valid_1's rmse: 4.91051
# [2700]	training's rmse: 4.3268	valid_1's rmse: 4.90893
# [2800]	training's rmse: 4.31614	valid_1's rmse: 4.90693
# [2900]	training's rmse: 4.30652	valid_1's rmse: 4.90442
# [3000]	training's rmse: 4.29649	valid_1's rmse: 4.90019
# [3100]	training's rmse: 4.28752	valid_1's rmse: 4.89689
# [3200]	training's rmse: 4.27744	valid_1's rmse: 4.89299
# [3300]	training's rmse: 4.26872	valid_1's rmse: 4.88833
# [3400]	training's rmse: 4.25979	valid_1's rmse: 4.8845
# [3500]	training's rmse: 4.25071	valid_1's rmse: 4.88125
# [3600]	training's rmse: 4.24171	valid_1's rmse: 4.87784
# [3700]	training's rmse: 4.2332	valid_1's rmse: 4.87443
# [3800]	training's rmse: 4.2261	valid_1's rmse: 4.87244
# [3900]	training's rmse: 4.21784	valid_1's rmse: 4.87105
# [4000]	training's rmse: 4.20935	valid_1's rmse: 4.86809
# [4100]	training's rmse: 4.20165	valid_1's rmse: 4.86559
# [4200]	training's rmse: 4.19318	valid_1's rmse: 4.86298
# [4300]	training's rmse: 4.18446	valid_1's rmse: 4.85682
# [4400]	training's rmse: 4.17664	valid_1's rmse: 4.8541
# [4500]	training's rmse: 4.1696	valid_1's rmse: 4.85217
# [4600]	training's rmse: 4.16299	valid_1's rmse: 4.84958
# [4700]	training's rmse: 4.15676	valid_1's rmse: 4.84685
# [4800]	training's rmse: 4.15045	valid_1's rmse: 4.84503
# [4900]	training's rmse: 4.14446	valid_1's rmse: 4.84288
# [5000]	training's rmse: 4.13766	valid_1's rmse: 4.83979
# [5100]	training's rmse: 4.13125	valid_1's rmse: 4.83826
# [5200]	training's rmse: 4.12395	valid_1's rmse: 4.83616
# [5300]	training's rmse: 4.11779	valid_1's rmse: 4.83374
# [5400]	training's rmse: 4.11194	valid_1's rmse: 4.83203
# [5500]	training's rmse: 4.10571	valid_1's rmse: 4.83027
# [5600]	training's rmse: 4.09959	valid_1's rmse: 4.82896
# [5700]	training's rmse: 4.09347	valid_1's rmse: 4.82701
# [5800]	training's rmse: 4.08787	valid_1's rmse: 4.82602
# [5900]	training's rmse: 4.0817	valid_1's rmse: 4.82377
# [6000]	training's rmse: 4.07685	valid_1's rmse: 4.82229
# [6100]	training's rmse: 4.07137	valid_1's rmse: 4.81995
# [6200]	training's rmse: 4.0657	valid_1's rmse: 4.8192
# [6300]	training's rmse: 4.05981	valid_1's rmse: 4.81771
# [6400]	training's rmse: 4.05406	valid_1's rmse: 4.8173
# [6500]	training's rmse: 4.04885	valid_1's rmse: 4.81593
# [6600]	training's rmse: 4.04327	valid_1's rmse: 4.81403
# [6700]	training's rmse: 4.03764	valid_1's rmse: 4.81254
# [6800]	training's rmse: 4.03149	valid_1's rmse: 4.81018
# [6900]	training's rmse: 4.02639	valid_1's rmse: 4.80883
# [7000]	training's rmse: 4.02064	valid_1's rmse: 4.80537
# [7100]	training's rmse: 4.01497	valid_1's rmse: 4.80341
# [7200]	training's rmse: 4.00931	valid_1's rmse: 4.80319
# [7300]	training's rmse: 4.00391	valid_1's rmse: 4.8021
# [7400]	training's rmse: 3.99908	valid_1's rmse: 4.80152
# [7500]	training's rmse: 3.9941	valid_1's rmse: 4.80004
# [7600]	training's rmse: 3.98954	valid_1's rmse: 4.79981
# [7700]	training's rmse: 3.98472	valid_1's rmse: 4.79794
# [7800]	training's rmse: 3.97955	valid_1's rmse: 4.79782
# [7900]	training's rmse: 3.97478	valid_1's rmse: 4.79736
# [8000]	training's rmse: 3.96964	valid_1's rmse: 4.79512
# [8100]	training's rmse: 3.96453	valid_1's rmse: 4.79286
# [8200]	training's rmse: 3.95993	valid_1's rmse: 4.79306
# [8300]	training's rmse: 3.95497	valid_1's rmse: 4.79178
# [8400]	training's rmse: 3.95108	valid_1's rmse: 4.79204
# [8500]	training's rmse: 3.94684	valid_1's rmse: 4.79019
# [8600]	training's rmse: 3.94272	valid_1's rmse: 4.78992
# [8700]	training's rmse: 3.93824	valid_1's rmse: 4.78801
# [8800]	training's rmse: 3.93376	valid_1's rmse: 4.78684
# [8900]	training's rmse: 3.9291	valid_1's rmse: 4.78513
# [9000]	training's rmse: 3.925	valid_1's rmse: 4.78441
# [9100]	training's rmse: 3.92156	valid_1's rmse: 4.78439
# [9200]	training's rmse: 3.9177	valid_1's rmse: 4.78272
# [9300]	training's rmse: 3.91391	valid_1's rmse: 4.78237
# [9400]	training's rmse: 3.90999	valid_1's rmse: 4.78255
# [9500]	training's rmse: 3.90565	valid_1's rmse: 4.78304
# Early stopping, best iteration is:
# [9308]	training's rmse: 3.91357	valid_1's rmse: 4.7821
# Fold  4 RMSE : 4.782099
#
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 5.99986	valid_1's rmse: 5.98349
# [200]	training's rmse: 5.15491	valid_1's rmse: 5.2313
# [300]	training's rmse: 4.99769	valid_1's rmse: 5.09092
# [400]	training's rmse: 4.90806	valid_1's rmse: 5.00457
# [500]	training's rmse: 4.84781	valid_1's rmse: 4.96187
# [600]	training's rmse: 4.79936	valid_1's rmse: 4.92767
# [700]	training's rmse: 4.75863	valid_1's rmse: 4.90245
# [800]	training's rmse: 4.72284	valid_1's rmse: 4.88133
# [900]	training's rmse: 4.68895	valid_1's rmse: 4.86442
# [1000]	training's rmse: 4.66258	valid_1's rmse: 4.85043
# [1100]	training's rmse: 4.63742	valid_1's rmse: 4.83968
# [1200]	training's rmse: 4.61465	valid_1's rmse: 4.82692
# [1300]	training's rmse: 4.59168	valid_1's rmse: 4.81632
# [1400]	training's rmse: 4.57054	valid_1's rmse: 4.80839
# [1500]	training's rmse: 4.55027	valid_1's rmse: 4.79883
# [1600]	training's rmse: 4.53329	valid_1's rmse: 4.79175
# [1700]	training's rmse: 4.51568	valid_1's rmse: 4.78425
# [1800]	training's rmse: 4.49976	valid_1's rmse: 4.78061
# [1900]	training's rmse: 4.4842	valid_1's rmse: 4.77422
# [2000]	training's rmse: 4.46898	valid_1's rmse: 4.77003
# [2100]	training's rmse: 4.45576	valid_1's rmse: 4.76581
# [2200]	training's rmse: 4.44296	valid_1's rmse: 4.76399
# [2300]	training's rmse: 4.42894	valid_1's rmse: 4.76251
# [2400]	training's rmse: 4.41634	valid_1's rmse: 4.75752
# [2500]	training's rmse: 4.40358	valid_1's rmse: 4.75414
# [2600]	training's rmse: 4.39098	valid_1's rmse: 4.75092
# [2700]	training's rmse: 4.38035	valid_1's rmse: 4.74939
# [2800]	training's rmse: 4.36978	valid_1's rmse: 4.75016
# [2900]	training's rmse: 4.35953	valid_1's rmse: 4.74667
# [3000]	training's rmse: 4.34797	valid_1's rmse: 4.74129
# [3100]	training's rmse: 4.33725	valid_1's rmse: 4.73599
# [3200]	training's rmse: 4.32833	valid_1's rmse: 4.73464
# [3300]	training's rmse: 4.3192	valid_1's rmse: 4.73187
# [3400]	training's rmse: 4.30956	valid_1's rmse: 4.72687
# [3500]	training's rmse: 4.3007	valid_1's rmse: 4.72193
# [3600]	training's rmse: 4.29246	valid_1's rmse: 4.71909
# [3700]	training's rmse: 4.2849	valid_1's rmse: 4.7157
# [3800]	training's rmse: 4.27816	valid_1's rmse: 4.71428
# [3900]	training's rmse: 4.27075	valid_1's rmse: 4.71064
# [4000]	training's rmse: 4.26327	valid_1's rmse: 4.70862
# [4100]	training's rmse: 4.25651	valid_1's rmse: 4.70711
# [4200]	training's rmse: 4.24959	valid_1's rmse: 4.70572
# [4300]	training's rmse: 4.2429	valid_1's rmse: 4.70232
# [4400]	training's rmse: 4.23689	valid_1's rmse: 4.69981
# [4500]	training's rmse: 4.22996	valid_1's rmse: 4.69787
# [4600]	training's rmse: 4.22184	valid_1's rmse: 4.69405
# [4700]	training's rmse: 4.21434	valid_1's rmse: 4.69122
# [4800]	training's rmse: 4.20751	valid_1's rmse: 4.68813
# [4900]	training's rmse: 4.20118	valid_1's rmse: 4.68656
# [5000]	training's rmse: 4.19474	valid_1's rmse: 4.68327
# [5100]	training's rmse: 4.18818	valid_1's rmse: 4.68232
# [5200]	training's rmse: 4.18124	valid_1's rmse: 4.6773
# [5300]	training's rmse: 4.17308	valid_1's rmse: 4.67267
# [5400]	training's rmse: 4.16609	valid_1's rmse: 4.67097
# [5500]	training's rmse: 4.15926	valid_1's rmse: 4.66825
# [5600]	training's rmse: 4.1517	valid_1's rmse: 4.66694
# [5700]	training's rmse: 4.14519	valid_1's rmse: 4.66454
# [5800]	training's rmse: 4.13858	valid_1's rmse: 4.66279
# [5900]	training's rmse: 4.13071	valid_1's rmse: 4.65971
# [6000]	training's rmse: 4.12459	valid_1's rmse: 4.65707
# [6100]	training's rmse: 4.11745	valid_1's rmse: 4.65522
# [6200]	training's rmse: 4.11031	valid_1's rmse: 4.6525
# [6300]	training's rmse: 4.10295	valid_1's rmse: 4.6495
# [6400]	training's rmse: 4.09514	valid_1's rmse: 4.64592
# [6500]	training's rmse: 4.08728	valid_1's rmse: 4.64216
# [6600]	training's rmse: 4.08084	valid_1's rmse: 4.63971
# [6700]	training's rmse: 4.07411	valid_1's rmse: 4.63746
# [6800]	training's rmse: 4.06758	valid_1's rmse: 4.63657
# [6900]	training's rmse: 4.06056	valid_1's rmse: 4.63428
# [7000]	training's rmse: 4.05421	valid_1's rmse: 4.63378
# [7100]	training's rmse: 4.04838	valid_1's rmse: 4.63118
# [7200]	training's rmse: 4.04229	valid_1's rmse: 4.62844
# [7300]	training's rmse: 4.03627	valid_1's rmse: 4.62675
# [7400]	training's rmse: 4.03032	valid_1's rmse: 4.62436
# [7500]	training's rmse: 4.02404	valid_1's rmse: 4.623
# [7600]	training's rmse: 4.01829	valid_1's rmse: 4.62073
# [7700]	training's rmse: 4.01264	valid_1's rmse: 4.62066
# [7800]	training's rmse: 4.00728	valid_1's rmse: 4.618
# [7900]	training's rmse: 4.00175	valid_1's rmse: 4.61753
# [8000]	training's rmse: 3.9967	valid_1's rmse: 4.61679
# [8100]	training's rmse: 3.99181	valid_1's rmse: 4.6151
# [8200]	training's rmse: 3.98685	valid_1's rmse: 4.61387
# [8300]	training's rmse: 3.9818	valid_1's rmse: 4.61211
# [8400]	training's rmse: 3.97722	valid_1's rmse: 4.61156
# [8500]	training's rmse: 3.97246	valid_1's rmse: 4.61016
# [8600]	training's rmse: 3.96815	valid_1's rmse: 4.60908
# [8700]	training's rmse: 3.96377	valid_1's rmse: 4.60833
# [8800]	training's rmse: 3.95935	valid_1's rmse: 4.60732
# [8900]	training's rmse: 3.95446	valid_1's rmse: 4.60636
# [9000]	training's rmse: 3.94988	valid_1's rmse: 4.6054
# [9100]	training's rmse: 3.94574	valid_1's rmse: 4.60496
# [9200]	training's rmse: 3.9416	valid_1's rmse: 4.60254
# [9300]	training's rmse: 3.93709	valid_1's rmse: 4.60048
# [9400]	training's rmse: 3.93332	valid_1's rmse: 4.59688
# [9500]	training's rmse: 3.92945	valid_1's rmse: 4.59439
# [9600]	training's rmse: 3.92592	valid_1's rmse: 4.59431
# [9700]	training's rmse: 3.92131	valid_1's rmse: 4.59223
# [9800]	training's rmse: 3.91668	valid_1's rmse: 4.59133
# [9900]	training's rmse: 3.91213	valid_1's rmse: 4.59025
# [10000]	training's rmse: 3.90737	valid_1's rmse: 4.58938
# [10100]	training's rmse: 3.90281	valid_1's rmse: 4.58701
# [10200]	training's rmse: 3.89842	valid_1's rmse: 4.58655
# [10300]	training's rmse: 3.89389	valid_1's rmse: 4.58552
# [10400]	training's rmse: 3.88928	valid_1's rmse: 4.5845
# [10500]	training's rmse: 3.88513	valid_1's rmse: 4.58425
# [10600]	training's rmse: 3.88131	valid_1's rmse: 4.58359
# [10700]	training's rmse: 3.87832	valid_1's rmse: 4.58396
# [10800]	training's rmse: 3.87445	valid_1's rmse: 4.58317
# Early stopping, best iteration is:
# [10617]	training's rmse: 3.88076	valid_1's rmse: 4.5828
# Fold  5 RMSE : 4.582801
#
# Full RMSE score 4.672037

# %%
df.loc[pred.index, 'hr_watch_rate'] = pred[['1001_fold_0', '1001_fold_1',
                                        '1001_fold_2', '1001_fold_3',
                                        '1001_fold_4']].mean(axis=1)

# %%
plt.plot(df['hr_watch_rate'])

# %%
df.to_csv('Crowdsignal_imputed_hr.csv', index=False)
