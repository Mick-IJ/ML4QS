# %%
import pandas as pd
import numpy as np
import gc
import time
from contextlib import contextmanager
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_squared_error as mse
from sklearn.model_selection import KFold, StratifiedKFold
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook as tqdm
from sklearn.model_selection import train_test_split as tts
# %matplotlib inline

# %%
df = pd.read_csv(r'../Python3Code/intermediate_datafiles/chapter2_result.csv')

cols = ['acc_phone_x', 'acc_phone_y', 'acc_phone_z',
       'acc_watch_x', 'acc_watch_y', 'acc_watch_z', 'gyr_phone_x',
       'gyr_phone_y', 'gyr_phone_z', 'gyr_watch_x', 'gyr_watch_y',
       'gyr_watch_z', 'hr_watch_rate',
       'light_phone_lux', 'mag_phone_x', 'mag_phone_y', 'mag_phone_z', 
        'mag_watch_x', 'mag_watch_y', 'mag_watch_z', 'press_phone_pressure']

df = df[cols]

# %%
for column in df.columns:
    df.loc[(df[column] > (df[column].mean() + 4*df[column].std())), column] = np.nan
    df.loc[(df[column] < (df[column].mean() - 4*df[column].std())), column] = np.nan

# %% [markdown]
# # BASELINE

# %%
heartrate = df[df['hr_watch_rate'].notnull()]['hr_watch_rate']
baseline_pred = np.repeat(heartrate.mean(), len(heartrate))
print('Baseline RMSE:', round(np.sqrt(mse(heartrate, baseline_pred)), 3))
# Out:
# Baseline RMSE: 35.23

# %%
plt.plot(df['hr_watch_rate'].fillna(heartrate.mean()))

# %% [markdown]
# # INTERPOLATION

# %%
plt.plot(df['hr_watch_rate'].interpolate())

# %% [markdown]
# # MODEL

# %%
def kfold_lightgbm(df, num_folds, stratified = False, debug= False, seed = 1001):
    # Divide in training/validation and test data
    train_df = df[df['hr_watch_rate'].notnull()]
    test_df = df[df['hr_watch_rate'].isnull()]
        
    print("Starting LightGBM. Train shape: {}, test shape: {}".format(train_df.shape, test_df.shape))
    del df
    # Cross validation model
    if stratified:
        folds = StratifiedKFold(n_splits= num_folds, shuffle=True, random_state=seed)
    else:
        folds = KFold(n_splits= num_folds, shuffle=True, random_state=seed)
    # Create arrays and dataframes to store results
    oof_preds = np.zeros(train_df.shape[0])
    sub_preds = np.zeros(test_df.shape[0])
    feature_importance_split_df = pd.DataFrame()
    feature_importance_gain_df = pd.DataFrame()
    fold_prediction = test_df.copy()

    feats = [f for f in train_df.columns if f not in ['hr_watch_rate']]
    
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[feats], train_df['hr_watch_rate'])):
        train_x, train_y = train_df[feats].iloc[train_idx], train_df['hr_watch_rate'].iloc[train_idx]
        valid_x, valid_y = train_df[feats].iloc[valid_idx], train_df['hr_watch_rate'].iloc[valid_idx]

        # LightGBM parameters found by Bayesian optimization
        clf = LGBMRegressor(
            metric = 'rmse',
            nthread=-1,
            n_estimators=100000,
            learning_rate=0.15,
            num_leaves=10,
            colsample_bytree=.6,
            subsample=0.6,
            max_depth=3,
            reg_alpha=.7,
            reg_lambda=.9,
            min_child_samples = 1200,
            min_child_weight = 60,
            min_data_per_group = 1200,
            min_data_in_bin = 300,
            silent=-1,
            verbose=-1)

        clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], 
            eval_metric= 'rmse', verbose= 100, early_stopping_rounds= 200)
        
        oof_preds[valid_idx] = clf.predict(valid_x, num_iteration=clf.best_iteration_)
        
        test_pred =  clf.predict(test_df[feats], num_iteration=clf.best_iteration_)
        sub_preds += test_pred / folds.n_splits
        
        fold_prediction.loc[:, str(seed) + '_fold_' + str(n_fold)] = test_pred

        fold_importance_df = pd.DataFrame()
        fold_importance_df["feature"] = feats
        fold_importance_df["importance"] = clf.booster_.feature_importance(importance_type = 'split')
        fold_importance_df["fold"] = n_fold + 1
        feature_importance_split_df = pd.concat([feature_importance_split_df, fold_importance_df], axis=0)
        
        fold_importance_df2 = pd.DataFrame()
        fold_importance_df2["feature"] = feats
        fold_importance_df2["importance"] = clf.booster_.feature_importance(importance_type = 'gain')
        fold_importance_df2["fold"] = n_fold + 1
        feature_importance_gain_df = pd.concat([feature_importance_gain_df, fold_importance_df2], axis=0)        
        
        print('Fold %2d RMSE : %.6f' % (n_fold + 1, np.sqrt(mse(valid_y, oof_preds[valid_idx]))))
        print()
        del clf, train_x, train_y, valid_x, valid_y

    print('Full RMSE score %.6f' % np.sqrt(mse(train_df['hr_watch_rate'], oof_preds)))
 
    display_importances(feature_importance_split_df)
    display_importances(feature_importance_gain_df)
    return feature_importance_split_df, feature_importance_gain_df, fold_prediction

# Display/plot feature importance
def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", 
                                                                                                   ascending=False)[:40].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    plt.figure(figsize=(8, 10))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()

# %%
split, gain, pred = kfold_lightgbm(df, 5)
# Out:
# Starting LightGBM. Train shape: (7511, 21), test shape: (24327, 21)
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 20.7045	valid_1's rmse: 20.5547
# [200]	training's rmse: 19.3037	valid_1's rmse: 19.364
# [300]	training's rmse: 18.5381	valid_1's rmse: 18.7954
# [400]	training's rmse: 17.9114	valid_1's rmse: 18.3418
# [500]	training's rmse: 17.4221	valid_1's rmse: 18.0034
# [600]	training's rmse: 17.0308	valid_1's rmse: 17.7017
# [700]	training's rmse: 16.7027	valid_1's rmse: 17.4384
# [800]	training's rmse: 16.4061	valid_1's rmse: 17.2547
# [900]	training's rmse: 16.1644	valid_1's rmse: 17.0909
# [1000]	training's rmse: 15.954	valid_1's rmse: 16.9794
# [1100]	training's rmse: 15.7628	valid_1's rmse: 16.86
# [1200]	training's rmse: 15.5741	valid_1's rmse: 16.7641
# [1300]	training's rmse: 15.4046	valid_1's rmse: 16.6693
# [1400]	training's rmse: 15.2589	valid_1's rmse: 16.5855
# [1500]	training's rmse: 15.1182	valid_1's rmse: 16.4911
# [1600]	training's rmse: 14.9844	valid_1's rmse: 16.4247
# [1700]	training's rmse: 14.8527	valid_1's rmse: 16.365
# [1800]	training's rmse: 14.7327	valid_1's rmse: 16.2807
# [1900]	training's rmse: 14.6253	valid_1's rmse: 16.2302
# [2000]	training's rmse: 14.5237	valid_1's rmse: 16.1705
# [2100]	training's rmse: 14.4186	valid_1's rmse: 16.1089
# [2200]	training's rmse: 14.328	valid_1's rmse: 16.0666
# [2300]	training's rmse: 14.2319	valid_1's rmse: 16.0088
# [2400]	training's rmse: 14.1453	valid_1's rmse: 15.9405
# [2500]	training's rmse: 14.0592	valid_1's rmse: 15.8934
# [2600]	training's rmse: 13.9779	valid_1's rmse: 15.8419
# [2700]	training's rmse: 13.9019	valid_1's rmse: 15.7942
# [2800]	training's rmse: 13.8213	valid_1's rmse: 15.7529
# [2900]	training's rmse: 13.7481	valid_1's rmse: 15.7188
# [3000]	training's rmse: 13.6839	valid_1's rmse: 15.6914
# [3100]	training's rmse: 13.6134	valid_1's rmse: 15.6425
# [3200]	training's rmse: 13.5542	valid_1's rmse: 15.6082
# [3300]	training's rmse: 13.4942	valid_1's rmse: 15.5793
# [3400]	training's rmse: 13.4329	valid_1's rmse: 15.5407
# [3500]	training's rmse: 13.3739	valid_1's rmse: 15.5154
# [3600]	training's rmse: 13.3268	valid_1's rmse: 15.4841
# [3700]	training's rmse: 13.2753	valid_1's rmse: 15.4659
# [3800]	training's rmse: 13.2217	valid_1's rmse: 15.4522
# [3900]	training's rmse: 13.1728	valid_1's rmse: 15.4279
# [4000]	training's rmse: 13.1207	valid_1's rmse: 15.4075
# [4100]	training's rmse: 13.0724	valid_1's rmse: 15.3815
# [4200]	training's rmse: 13.0253	valid_1's rmse: 15.3592
# [4300]	training's rmse: 12.9803	valid_1's rmse: 15.3324
# [4400]	training's rmse: 12.9324	valid_1's rmse: 15.3121
# [4500]	training's rmse: 12.8868	valid_1's rmse: 15.2947
# [4600]	training's rmse: 12.8426	valid_1's rmse: 15.2794
# [4700]	training's rmse: 12.7972	valid_1's rmse: 15.2691
# [4800]	training's rmse: 12.7559	valid_1's rmse: 15.2526
# [4900]	training's rmse: 12.717	valid_1's rmse: 15.2459
# [5000]	training's rmse: 12.6719	valid_1's rmse: 15.2168
# [5100]	training's rmse: 12.6263	valid_1's rmse: 15.2052
# [5200]	training's rmse: 12.5889	valid_1's rmse: 15.1904
# [5300]	training's rmse: 12.5474	valid_1's rmse: 15.1811
# [5400]	training's rmse: 12.508	valid_1's rmse: 15.1648
# [5500]	training's rmse: 12.4724	valid_1's rmse: 15.1477
# [5600]	training's rmse: 12.4341	valid_1's rmse: 15.1322
# [5700]	training's rmse: 12.3997	valid_1's rmse: 15.1188
# [5800]	training's rmse: 12.3662	valid_1's rmse: 15.108
# [5900]	training's rmse: 12.3301	valid_1's rmse: 15.0888
# [6000]	training's rmse: 12.2961	valid_1's rmse: 15.0697
# [6100]	training's rmse: 12.2599	valid_1's rmse: 15.0628
# [6200]	training's rmse: 12.2218	valid_1's rmse: 15.0449
# [6300]	training's rmse: 12.1861	valid_1's rmse: 15.0395
# [6400]	training's rmse: 12.1565	valid_1's rmse: 15.0267
# [6500]	training's rmse: 12.1227	valid_1's rmse: 15.0085
# [6600]	training's rmse: 12.0888	valid_1's rmse: 14.9929
# [6700]	training's rmse: 12.0592	valid_1's rmse: 14.9806
# [6800]	training's rmse: 12.0283	valid_1's rmse: 14.9703
# [6900]	training's rmse: 11.9983	valid_1's rmse: 14.9627
# [7000]	training's rmse: 11.9655	valid_1's rmse: 14.9458
# [7100]	training's rmse: 11.9317	valid_1's rmse: 14.9349
# [7200]	training's rmse: 11.9058	valid_1's rmse: 14.9286
# [7300]	training's rmse: 11.8756	valid_1's rmse: 14.9242
# [7400]	training's rmse: 11.8459	valid_1's rmse: 14.9149
# [7500]	training's rmse: 11.8159	valid_1's rmse: 14.8971
# [7600]	training's rmse: 11.7856	valid_1's rmse: 14.8873
# [7700]	training's rmse: 11.7575	valid_1's rmse: 14.871
# [7800]	training's rmse: 11.727	valid_1's rmse: 14.8528
# [7900]	training's rmse: 11.6955	valid_1's rmse: 14.8407
# [8000]	training's rmse: 11.666	valid_1's rmse: 14.8391
# [8100]	training's rmse: 11.6384	valid_1's rmse: 14.8301
# [8200]	training's rmse: 11.6101	valid_1's rmse: 14.8279
# [8300]	training's rmse: 11.5816	valid_1's rmse: 14.8081
# [8400]	training's rmse: 11.5521	valid_1's rmse: 14.7935
# [8500]	training's rmse: 11.5258	valid_1's rmse: 14.7833
# [8600]	training's rmse: 11.5009	valid_1's rmse: 14.7716
# [8700]	training's rmse: 11.4755	valid_1's rmse: 14.7744
# [8800]	training's rmse: 11.4504	valid_1's rmse: 14.7636
# [8900]	training's rmse: 11.4255	valid_1's rmse: 14.7465
# [9000]	training's rmse: 11.401	valid_1's rmse: 14.7368
# [9100]	training's rmse: 11.3777	valid_1's rmse: 14.7332
# [9200]	training's rmse: 11.3512	valid_1's rmse: 14.7255
# [9300]	training's rmse: 11.3284	valid_1's rmse: 14.7288
# [9400]	training's rmse: 11.3048	valid_1's rmse: 14.7179
# [9500]	training's rmse: 11.2816	valid_1's rmse: 14.7071
# [9600]	training's rmse: 11.26	valid_1's rmse: 14.713
# [9700]	training's rmse: 11.2369	valid_1's rmse: 14.7079
# Early stopping, best iteration is:
# [9503]	training's rmse: 11.2811	valid_1's rmse: 14.7061
# Fold  1 RMSE : 14.706052
#
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 20.3227	valid_1's rmse: 20.8741
# [200]	training's rmse: 18.9932	valid_1's rmse: 19.7526
# [300]	training's rmse: 18.1994	valid_1's rmse: 19.0748
# [400]	training's rmse: 17.636	valid_1's rmse: 18.602
# [500]	training's rmse: 17.2079	valid_1's rmse: 18.2921
# [600]	training's rmse: 16.8605	valid_1's rmse: 18.0201
# [700]	training's rmse: 16.5368	valid_1's rmse: 17.7598
# [800]	training's rmse: 16.2899	valid_1's rmse: 17.5698
# [900]	training's rmse: 16.0463	valid_1's rmse: 17.3654
# [1000]	training's rmse: 15.8403	valid_1's rmse: 17.2668
# [1100]	training's rmse: 15.664	valid_1's rmse: 17.169
# [1200]	training's rmse: 15.4945	valid_1's rmse: 17.0588
# [1300]	training's rmse: 15.3428	valid_1's rmse: 16.9723
# [1400]	training's rmse: 15.2062	valid_1's rmse: 16.8983
# [1500]	training's rmse: 15.0732	valid_1's rmse: 16.8287
# [1600]	training's rmse: 14.939	valid_1's rmse: 16.7484
# [1700]	training's rmse: 14.8272	valid_1's rmse: 16.7039
# [1800]	training's rmse: 14.7123	valid_1's rmse: 16.6543
# [1900]	training's rmse: 14.5957	valid_1's rmse: 16.5884
# [2000]	training's rmse: 14.4917	valid_1's rmse: 16.5323
# [2100]	training's rmse: 14.3978	valid_1's rmse: 16.4802
# [2200]	training's rmse: 14.3062	valid_1's rmse: 16.4399
# [2300]	training's rmse: 14.2091	valid_1's rmse: 16.3802
# [2400]	training's rmse: 14.1186	valid_1's rmse: 16.3378
# [2500]	training's rmse: 14.041	valid_1's rmse: 16.3038
# [2600]	training's rmse: 13.9667	valid_1's rmse: 16.2503
# [2700]	training's rmse: 13.8987	valid_1's rmse: 16.2198
# [2800]	training's rmse: 13.8304	valid_1's rmse: 16.1933
# [2900]	training's rmse: 13.7614	valid_1's rmse: 16.1751
# [3000]	training's rmse: 13.6953	valid_1's rmse: 16.1514
# [3100]	training's rmse: 13.6321	valid_1's rmse: 16.1271
# [3200]	training's rmse: 13.5724	valid_1's rmse: 16.1045
# [3300]	training's rmse: 13.5047	valid_1's rmse: 16.0771
# [3400]	training's rmse: 13.446	valid_1's rmse: 16.0521
# [3500]	training's rmse: 13.3905	valid_1's rmse: 16.027
# [3600]	training's rmse: 13.3342	valid_1's rmse: 16.0025
# [3700]	training's rmse: 13.2808	valid_1's rmse: 15.9836
# [3800]	training's rmse: 13.2302	valid_1's rmse: 15.9617
# [3900]	training's rmse: 13.1746	valid_1's rmse: 15.9308
# [4000]	training's rmse: 13.1172	valid_1's rmse: 15.9083
# [4100]	training's rmse: 13.0716	valid_1's rmse: 15.8891
# [4200]	training's rmse: 13.0233	valid_1's rmse: 15.8704
# [4300]	training's rmse: 12.9694	valid_1's rmse: 15.8454
# [4400]	training's rmse: 12.9266	valid_1's rmse: 15.8411
# [4500]	training's rmse: 12.8709	valid_1's rmse: 15.8093
# [4600]	training's rmse: 12.8236	valid_1's rmse: 15.7935
# [4700]	training's rmse: 12.7806	valid_1's rmse: 15.7763
# [4800]	training's rmse: 12.7326	valid_1's rmse: 15.7484
# [4900]	training's rmse: 12.6902	valid_1's rmse: 15.7413
# [5000]	training's rmse: 12.6489	valid_1's rmse: 15.7196
# [5100]	training's rmse: 12.6011	valid_1's rmse: 15.6989
# [5200]	training's rmse: 12.5609	valid_1's rmse: 15.6864
# [5300]	training's rmse: 12.5225	valid_1's rmse: 15.6748
# [5400]	training's rmse: 12.4819	valid_1's rmse: 15.6461
# [5500]	training's rmse: 12.4432	valid_1's rmse: 15.6374
# [5600]	training's rmse: 12.4094	valid_1's rmse: 15.6207
# [5700]	training's rmse: 12.3707	valid_1's rmse: 15.5949
# [5800]	training's rmse: 12.3345	valid_1's rmse: 15.5782
# [5900]	training's rmse: 12.3006	valid_1's rmse: 15.5626
# [6000]	training's rmse: 12.2625	valid_1's rmse: 15.5546
# [6100]	training's rmse: 12.227	valid_1's rmse: 15.5391
# [6200]	training's rmse: 12.1908	valid_1's rmse: 15.5309
# [6300]	training's rmse: 12.1582	valid_1's rmse: 15.5257
# [6400]	training's rmse: 12.1219	valid_1's rmse: 15.5085
# [6500]	training's rmse: 12.0873	valid_1's rmse: 15.5039
# [6600]	training's rmse: 12.0575	valid_1's rmse: 15.4945
# [6700]	training's rmse: 12.0303	valid_1's rmse: 15.4761
# [6800]	training's rmse: 12.0005	valid_1's rmse: 15.465
# [6900]	training's rmse: 11.9673	valid_1's rmse: 15.4574
# [7000]	training's rmse: 11.9441	valid_1's rmse: 15.4577
# [7100]	training's rmse: 11.9143	valid_1's rmse: 15.4453
# [7200]	training's rmse: 11.8838	valid_1's rmse: 15.4351
# [7300]	training's rmse: 11.856	valid_1's rmse: 15.4292
# [7400]	training's rmse: 11.8281	valid_1's rmse: 15.413
# [7500]	training's rmse: 11.7978	valid_1's rmse: 15.3954
# [7600]	training's rmse: 11.7711	valid_1's rmse: 15.3879
# [7700]	training's rmse: 11.7451	valid_1's rmse: 15.376
# [7800]	training's rmse: 11.7187	valid_1's rmse: 15.3642
# [7900]	training's rmse: 11.6948	valid_1's rmse: 15.3551
# [8000]	training's rmse: 11.6697	valid_1's rmse: 15.3458
# [8100]	training's rmse: 11.6423	valid_1's rmse: 15.345
# [8200]	training's rmse: 11.6141	valid_1's rmse: 15.3383
# [8300]	training's rmse: 11.5863	valid_1's rmse: 15.3266
# [8400]	training's rmse: 11.5577	valid_1's rmse: 15.3101
# [8500]	training's rmse: 11.5258	valid_1's rmse: 15.2886
# [8600]	training's rmse: 11.4982	valid_1's rmse: 15.2782
# [8700]	training's rmse: 11.4734	valid_1's rmse: 15.2644
# [8800]	training's rmse: 11.4475	valid_1's rmse: 15.2573
# [8900]	training's rmse: 11.4228	valid_1's rmse: 15.2534
# [9000]	training's rmse: 11.3998	valid_1's rmse: 15.2519
# [9100]	training's rmse: 11.3807	valid_1's rmse: 15.2509
# [9200]	training's rmse: 11.3568	valid_1's rmse: 15.2484
# [9300]	training's rmse: 11.3347	valid_1's rmse: 15.2499
# [9400]	training's rmse: 11.3141	valid_1's rmse: 15.2489
# [9500]	training's rmse: 11.2898	valid_1's rmse: 15.2397
# [9600]	training's rmse: 11.2658	valid_1's rmse: 15.2366
# [9700]	training's rmse: 11.2448	valid_1's rmse: 15.2361
# [9800]	training's rmse: 11.2235	valid_1's rmse: 15.232
# [9900]	training's rmse: 11.1991	valid_1's rmse: 15.2197
# [10000]	training's rmse: 11.1729	valid_1's rmse: 15.212
# [10100]	training's rmse: 11.1485	valid_1's rmse: 15.2075
# [10200]	training's rmse: 11.1248	valid_1's rmse: 15.2007
# [10300]	training's rmse: 11.1013	valid_1's rmse: 15.1895
# [10400]	training's rmse: 11.0784	valid_1's rmse: 15.1863
# [10500]	training's rmse: 11.056	valid_1's rmse: 15.1805
# [10600]	training's rmse: 11.0347	valid_1's rmse: 15.1717
# [10700]	training's rmse: 11.0128	valid_1's rmse: 15.1745
# [10800]	training's rmse: 10.9938	valid_1's rmse: 15.1607
# [10900]	training's rmse: 10.9742	valid_1's rmse: 15.1639
# [11000]	training's rmse: 10.9552	valid_1's rmse: 15.1614
# [11100]	training's rmse: 10.9326	valid_1's rmse: 15.1578
# [11200]	training's rmse: 10.9098	valid_1's rmse: 15.1511
# [11300]	training's rmse: 10.8881	valid_1's rmse: 15.1405
# [11400]	training's rmse: 10.8675	valid_1's rmse: 15.13
# [11500]	training's rmse: 10.8492	valid_1's rmse: 15.1295
# [11600]	training's rmse: 10.8274	valid_1's rmse: 15.1214
# [11700]	training's rmse: 10.8076	valid_1's rmse: 15.1198
# [11800]	training's rmse: 10.7883	valid_1's rmse: 15.1118
# [11900]	training's rmse: 10.7677	valid_1's rmse: 15.1062
# [12000]	training's rmse: 10.749	valid_1's rmse: 15.1044
# [12100]	training's rmse: 10.7263	valid_1's rmse: 15.0961
# [12200]	training's rmse: 10.7084	valid_1's rmse: 15.1005
# [12300]	training's rmse: 10.6879	valid_1's rmse: 15.0926
# [12400]	training's rmse: 10.6705	valid_1's rmse: 15.0873
# [12500]	training's rmse: 10.6504	valid_1's rmse: 15.0806
# [12600]	training's rmse: 10.6284	valid_1's rmse: 15.0786
# [12700]	training's rmse: 10.6089	valid_1's rmse: 15.0764
# [12800]	training's rmse: 10.5918	valid_1's rmse: 15.0712
# [12900]	training's rmse: 10.5738	valid_1's rmse: 15.0644
# [13000]	training's rmse: 10.554	valid_1's rmse: 15.0627
# [13100]	training's rmse: 10.5357	valid_1's rmse: 15.0601
# Early stopping, best iteration is:
# [12958]	training's rmse: 10.5608	valid_1's rmse: 15.0591
# Fold  2 RMSE : 15.059059
#
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 20.7043	valid_1's rmse: 20.6283
# [200]	training's rmse: 19.271	valid_1's rmse: 19.3112
# [300]	training's rmse: 18.4872	valid_1's rmse: 18.5618
# [400]	training's rmse: 17.941	valid_1's rmse: 18.0867
# [500]	training's rmse: 17.5018	valid_1's rmse: 17.6847
# [600]	training's rmse: 17.1421	valid_1's rmse: 17.4098
# [700]	training's rmse: 16.7696	valid_1's rmse: 17.1551
# [800]	training's rmse: 16.5281	valid_1's rmse: 16.9898
# [900]	training's rmse: 16.303	valid_1's rmse: 16.8169
# [1000]	training's rmse: 16.0675	valid_1's rmse: 16.6681
# [1100]	training's rmse: 15.878	valid_1's rmse: 16.5396
# [1200]	training's rmse: 15.7038	valid_1's rmse: 16.4235
# [1300]	training's rmse: 15.5411	valid_1's rmse: 16.3104
# [1400]	training's rmse: 15.3854	valid_1's rmse: 16.218
# [1500]	training's rmse: 15.237	valid_1's rmse: 16.1397
# [1600]	training's rmse: 15.1029	valid_1's rmse: 16.0907
# [1700]	training's rmse: 14.974	valid_1's rmse: 16.0373
# [1800]	training's rmse: 14.8696	valid_1's rmse: 16.0034
# [1900]	training's rmse: 14.7664	valid_1's rmse: 15.9282
# [2000]	training's rmse: 14.6614	valid_1's rmse: 15.8623
# [2100]	training's rmse: 14.5595	valid_1's rmse: 15.7989
# [2200]	training's rmse: 14.4701	valid_1's rmse: 15.7561
# [2300]	training's rmse: 14.3749	valid_1's rmse: 15.7143
# [2400]	training's rmse: 14.2839	valid_1's rmse: 15.6605
# [2500]	training's rmse: 14.1993	valid_1's rmse: 15.6076
# [2600]	training's rmse: 14.1172	valid_1's rmse: 15.5651
# [2700]	training's rmse: 14.0492	valid_1's rmse: 15.5351
# [2800]	training's rmse: 13.9872	valid_1's rmse: 15.4978
# [2900]	training's rmse: 13.9153	valid_1's rmse: 15.4611
# [3000]	training's rmse: 13.8454	valid_1's rmse: 15.4409
# [3100]	training's rmse: 13.7828	valid_1's rmse: 15.4198
# [3200]	training's rmse: 13.7195	valid_1's rmse: 15.379
# [3300]	training's rmse: 13.6497	valid_1's rmse: 15.3417
# [3400]	training's rmse: 13.5877	valid_1's rmse: 15.3127
# [3500]	training's rmse: 13.5293	valid_1's rmse: 15.2888
# [3600]	training's rmse: 13.4674	valid_1's rmse: 15.2483
# [3700]	training's rmse: 13.4049	valid_1's rmse: 15.2275
# [3800]	training's rmse: 13.3518	valid_1's rmse: 15.2108
# [3900]	training's rmse: 13.299	valid_1's rmse: 15.1984
# [4000]	training's rmse: 13.2485	valid_1's rmse: 15.1751
# [4100]	training's rmse: 13.1984	valid_1's rmse: 15.1457
# [4200]	training's rmse: 13.1442	valid_1's rmse: 15.1281
# [4300]	training's rmse: 13.0965	valid_1's rmse: 15.1029
# [4400]	training's rmse: 13.0504	valid_1's rmse: 15.0844
# [4500]	training's rmse: 13.0048	valid_1's rmse: 15.0626
# [4600]	training's rmse: 12.959	valid_1's rmse: 15.0331
# [4700]	training's rmse: 12.9137	valid_1's rmse: 15.0188
# [4800]	training's rmse: 12.8682	valid_1's rmse: 14.9893
# [4900]	training's rmse: 12.827	valid_1's rmse: 14.9644
# [5000]	training's rmse: 12.7839	valid_1's rmse: 14.9405
# [5100]	training's rmse: 12.7432	valid_1's rmse: 14.9127
# [5200]	training's rmse: 12.6996	valid_1's rmse: 14.8908
# [5300]	training's rmse: 12.6589	valid_1's rmse: 14.883
# [5400]	training's rmse: 12.6176	valid_1's rmse: 14.8491
# [5500]	training's rmse: 12.5764	valid_1's rmse: 14.8174
# [5600]	training's rmse: 12.5391	valid_1's rmse: 14.8068
# [5700]	training's rmse: 12.502	valid_1's rmse: 14.7818
# [5800]	training's rmse: 12.4643	valid_1's rmse: 14.7578
# [5900]	training's rmse: 12.424	valid_1's rmse: 14.752
# [6000]	training's rmse: 12.3864	valid_1's rmse: 14.7317
# [6100]	training's rmse: 12.3496	valid_1's rmse: 14.7131
# [6200]	training's rmse: 12.3123	valid_1's rmse: 14.6991
# [6300]	training's rmse: 12.2768	valid_1's rmse: 14.6911
# [6400]	training's rmse: 12.2402	valid_1's rmse: 14.6781
# [6500]	training's rmse: 12.2058	valid_1's rmse: 14.6606
# [6600]	training's rmse: 12.1723	valid_1's rmse: 14.6522
# [6700]	training's rmse: 12.1399	valid_1's rmse: 14.6419
# [6800]	training's rmse: 12.1079	valid_1's rmse: 14.636
# [6900]	training's rmse: 12.0796	valid_1's rmse: 14.6259
# [7000]	training's rmse: 12.0492	valid_1's rmse: 14.6085
# [7100]	training's rmse: 12.0179	valid_1's rmse: 14.594
# [7200]	training's rmse: 11.9881	valid_1's rmse: 14.5932
# [7300]	training's rmse: 11.9556	valid_1's rmse: 14.591
# [7400]	training's rmse: 11.925	valid_1's rmse: 14.5799
# [7500]	training's rmse: 11.8936	valid_1's rmse: 14.569
# [7600]	training's rmse: 11.8623	valid_1's rmse: 14.5657
# [7700]	training's rmse: 11.8349	valid_1's rmse: 14.5516
# [7800]	training's rmse: 11.8059	valid_1's rmse: 14.5362
# [7900]	training's rmse: 11.7767	valid_1's rmse: 14.5189
# [8000]	training's rmse: 11.7459	valid_1's rmse: 14.5101
# [8100]	training's rmse: 11.7151	valid_1's rmse: 14.5124
# [8200]	training's rmse: 11.6839	valid_1's rmse: 14.4862
# [8300]	training's rmse: 11.6544	valid_1's rmse: 14.4742
# [8400]	training's rmse: 11.6288	valid_1's rmse: 14.4691
# [8500]	training's rmse: 11.606	valid_1's rmse: 14.4597
# [8600]	training's rmse: 11.5772	valid_1's rmse: 14.4443
# [8700]	training's rmse: 11.5503	valid_1's rmse: 14.4345
# [8800]	training's rmse: 11.5211	valid_1's rmse: 14.4191
# [8900]	training's rmse: 11.4949	valid_1's rmse: 14.406
# [9000]	training's rmse: 11.4663	valid_1's rmse: 14.3886
# [9100]	training's rmse: 11.4417	valid_1's rmse: 14.3752
# [9200]	training's rmse: 11.4164	valid_1's rmse: 14.3658
# [9300]	training's rmse: 11.388	valid_1's rmse: 14.3601
# [9400]	training's rmse: 11.3644	valid_1's rmse: 14.3574
# [9500]	training's rmse: 11.3391	valid_1's rmse: 14.3471
# [9600]	training's rmse: 11.3127	valid_1's rmse: 14.3434
# [9700]	training's rmse: 11.2879	valid_1's rmse: 14.3392
# [9800]	training's rmse: 11.2649	valid_1's rmse: 14.3259
# [9900]	training's rmse: 11.2435	valid_1's rmse: 14.3243
# [10000]	training's rmse: 11.2194	valid_1's rmse: 14.317
# [10100]	training's rmse: 11.2004	valid_1's rmse: 14.309
# [10200]	training's rmse: 11.1782	valid_1's rmse: 14.2991
# [10300]	training's rmse: 11.1565	valid_1's rmse: 14.2941
# [10400]	training's rmse: 11.1355	valid_1's rmse: 14.2813
# [10500]	training's rmse: 11.112	valid_1's rmse: 14.2776
# [10600]	training's rmse: 11.0934	valid_1's rmse: 14.267
# [10700]	training's rmse: 11.0726	valid_1's rmse: 14.2648
# [10800]	training's rmse: 11.0519	valid_1's rmse: 14.2479
# [10900]	training's rmse: 11.0272	valid_1's rmse: 14.2494
# [11000]	training's rmse: 11.0049	valid_1's rmse: 14.239
# [11100]	training's rmse: 10.9839	valid_1's rmse: 14.2279
# [11200]	training's rmse: 10.9634	valid_1's rmse: 14.2253
# [11300]	training's rmse: 10.9434	valid_1's rmse: 14.2238
# [11400]	training's rmse: 10.9214	valid_1's rmse: 14.2204
# [11500]	training's rmse: 10.9024	valid_1's rmse: 14.2136
# [11600]	training's rmse: 10.8818	valid_1's rmse: 14.2065
# [11700]	training's rmse: 10.8578	valid_1's rmse: 14.2015
# [11800]	training's rmse: 10.8355	valid_1's rmse: 14.1946
# [11900]	training's rmse: 10.8143	valid_1's rmse: 14.1857
# [12000]	training's rmse: 10.7938	valid_1's rmse: 14.1717
# [12100]	training's rmse: 10.7752	valid_1's rmse: 14.1722
# [12200]	training's rmse: 10.7556	valid_1's rmse: 14.1617
# [12300]	training's rmse: 10.7375	valid_1's rmse: 14.1607
# [12400]	training's rmse: 10.7202	valid_1's rmse: 14.1492
# [12500]	training's rmse: 10.7015	valid_1's rmse: 14.1469
# [12600]	training's rmse: 10.6843	valid_1's rmse: 14.1413
# [12700]	training's rmse: 10.6642	valid_1's rmse: 14.1352
# [12800]	training's rmse: 10.6448	valid_1's rmse: 14.1323
# [12900]	training's rmse: 10.6291	valid_1's rmse: 14.1244
# [13000]	training's rmse: 10.6116	valid_1's rmse: 14.1234
# [13100]	training's rmse: 10.595	valid_1's rmse: 14.1207
# [13200]	training's rmse: 10.5786	valid_1's rmse: 14.1186
# [13300]	training's rmse: 10.5612	valid_1's rmse: 14.1178
# [13400]	training's rmse: 10.5434	valid_1's rmse: 14.1122
# [13500]	training's rmse: 10.528	valid_1's rmse: 14.1055
# [13600]	training's rmse: 10.5112	valid_1's rmse: 14.1004
# [13700]	training's rmse: 10.4938	valid_1's rmse: 14.0909
# [13800]	training's rmse: 10.4794	valid_1's rmse: 14.0906
# [13900]	training's rmse: 10.4637	valid_1's rmse: 14.0893
# [14000]	training's rmse: 10.4481	valid_1's rmse: 14.0798
# [14100]	training's rmse: 10.4319	valid_1's rmse: 14.0774
# [14200]	training's rmse: 10.4155	valid_1's rmse: 14.0699
# [14300]	training's rmse: 10.3974	valid_1's rmse: 14.0645
# [14400]	training's rmse: 10.3789	valid_1's rmse: 14.056
# [14500]	training's rmse: 10.3623	valid_1's rmse: 14.0552
# [14600]	training's rmse: 10.3441	valid_1's rmse: 14.0468
# [14700]	training's rmse: 10.3285	valid_1's rmse: 14.0398
# [14800]	training's rmse: 10.3128	valid_1's rmse: 14.0411
# [14900]	training's rmse: 10.2981	valid_1's rmse: 14.0326
# [15000]	training's rmse: 10.2831	valid_1's rmse: 14.0281
# [15100]	training's rmse: 10.2695	valid_1's rmse: 14.0298
# [15200]	training's rmse: 10.2556	valid_1's rmse: 14.0236
# [15300]	training's rmse: 10.2413	valid_1's rmse: 14.0176
# [15400]	training's rmse: 10.2271	valid_1's rmse: 14.0169
# [15500]	training's rmse: 10.2129	valid_1's rmse: 14.014
# [15600]	training's rmse: 10.1989	valid_1's rmse: 14.0126
# [15700]	training's rmse: 10.183	valid_1's rmse: 14.0112
# [15800]	training's rmse: 10.1682	valid_1's rmse: 14.0056
# [15900]	training's rmse: 10.1527	valid_1's rmse: 14.0073
# [16000]	training's rmse: 10.1373	valid_1's rmse: 14.0002
# [16100]	training's rmse: 10.1227	valid_1's rmse: 14.0004
# [16200]	training's rmse: 10.1062	valid_1's rmse: 13.9974
# [16300]	training's rmse: 10.0927	valid_1's rmse: 13.9944
# [16400]	training's rmse: 10.0783	valid_1's rmse: 13.9901
# [16500]	training's rmse: 10.0653	valid_1's rmse: 13.9842
# [16600]	training's rmse: 10.0502	valid_1's rmse: 13.9814
# [16700]	training's rmse: 10.0359	valid_1's rmse: 13.9746
# [16800]	training's rmse: 10.0213	valid_1's rmse: 13.9701
# [16900]	training's rmse: 10.0093	valid_1's rmse: 13.9685
# [17000]	training's rmse: 9.99611	valid_1's rmse: 13.9678
# [17100]	training's rmse: 9.98198	valid_1's rmse: 13.9588
# [17200]	training's rmse: 9.96718	valid_1's rmse: 13.9617
# [17300]	training's rmse: 9.95514	valid_1's rmse: 13.9582
# Early stopping, best iteration is:
# [17140]	training's rmse: 9.97628	valid_1's rmse: 13.9565
# Fold  3 RMSE : 13.956503
#
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 20.2833	valid_1's rmse: 21.5267
# [200]	training's rmse: 18.9176	valid_1's rmse: 20.3664
# [300]	training's rmse: 18.091	valid_1's rmse: 19.6505
# [400]	training's rmse: 17.4497	valid_1's rmse: 19.1063
# [500]	training's rmse: 17.0425	valid_1's rmse: 18.8134
# [600]	training's rmse: 16.6752	valid_1's rmse: 18.5264
# [700]	training's rmse: 16.3953	valid_1's rmse: 18.3149
# [800]	training's rmse: 16.1319	valid_1's rmse: 18.1278
# [900]	training's rmse: 15.8992	valid_1's rmse: 17.9733
# [1000]	training's rmse: 15.7024	valid_1's rmse: 17.8375
# [1100]	training's rmse: 15.5125	valid_1's rmse: 17.6969
# [1200]	training's rmse: 15.3367	valid_1's rmse: 17.5995
# [1300]	training's rmse: 15.1761	valid_1's rmse: 17.514
# [1400]	training's rmse: 15.0333	valid_1's rmse: 17.4122
# [1500]	training's rmse: 14.8937	valid_1's rmse: 17.3453
# [1600]	training's rmse: 14.7658	valid_1's rmse: 17.27
# [1700]	training's rmse: 14.6463	valid_1's rmse: 17.2155
# [1800]	training's rmse: 14.5321	valid_1's rmse: 17.1492
# [1900]	training's rmse: 14.4209	valid_1's rmse: 17.0776
# [2000]	training's rmse: 14.3153	valid_1's rmse: 17.0273
# [2100]	training's rmse: 14.2151	valid_1's rmse: 16.9694
# [2200]	training's rmse: 14.1151	valid_1's rmse: 16.9015
# [2300]	training's rmse: 14.0184	valid_1's rmse: 16.835
# [2400]	training's rmse: 13.9247	valid_1's rmse: 16.7819
# [2500]	training's rmse: 13.8335	valid_1's rmse: 16.7293
# [2600]	training's rmse: 13.7528	valid_1's rmse: 16.6808
# [2700]	training's rmse: 13.676	valid_1's rmse: 16.6531
# [2800]	training's rmse: 13.6006	valid_1's rmse: 16.6147
# [2900]	training's rmse: 13.527	valid_1's rmse: 16.5685
# [3000]	training's rmse: 13.4561	valid_1's rmse: 16.5414
# [3100]	training's rmse: 13.3927	valid_1's rmse: 16.504
# [3200]	training's rmse: 13.3316	valid_1's rmse: 16.4841
# [3300]	training's rmse: 13.2694	valid_1's rmse: 16.4555
# [3400]	training's rmse: 13.2054	valid_1's rmse: 16.4254
# [3500]	training's rmse: 13.1453	valid_1's rmse: 16.3919
# [3600]	training's rmse: 13.0917	valid_1's rmse: 16.3534
# [3700]	training's rmse: 13.0331	valid_1's rmse: 16.3296
# [3800]	training's rmse: 12.9764	valid_1's rmse: 16.3018
# [3900]	training's rmse: 12.9266	valid_1's rmse: 16.2789
# [4000]	training's rmse: 12.8751	valid_1's rmse: 16.2549
# [4100]	training's rmse: 12.8276	valid_1's rmse: 16.2388
# [4200]	training's rmse: 12.778	valid_1's rmse: 16.217
# [4300]	training's rmse: 12.7343	valid_1's rmse: 16.1959
# [4400]	training's rmse: 12.6946	valid_1's rmse: 16.1822
# [4500]	training's rmse: 12.6514	valid_1's rmse: 16.1645
# [4600]	training's rmse: 12.6042	valid_1's rmse: 16.1551
# [4700]	training's rmse: 12.5634	valid_1's rmse: 16.1316
# [4800]	training's rmse: 12.5169	valid_1's rmse: 16.1146
# [4900]	training's rmse: 12.4721	valid_1's rmse: 16.1133
# [5000]	training's rmse: 12.4303	valid_1's rmse: 16.1033
# [5100]	training's rmse: 12.3866	valid_1's rmse: 16.0902
# [5200]	training's rmse: 12.3497	valid_1's rmse: 16.0809
# [5300]	training's rmse: 12.3116	valid_1's rmse: 16.0645
# [5400]	training's rmse: 12.2733	valid_1's rmse: 16.0436
# [5500]	training's rmse: 12.2389	valid_1's rmse: 16.0317
# [5600]	training's rmse: 12.2051	valid_1's rmse: 16.0179
# [5700]	training's rmse: 12.1685	valid_1's rmse: 16.0037
# [5800]	training's rmse: 12.1305	valid_1's rmse: 15.9863
# [5900]	training's rmse: 12.1003	valid_1's rmse: 15.9711
# [6000]	training's rmse: 12.0679	valid_1's rmse: 15.9622
# [6100]	training's rmse: 12.0309	valid_1's rmse: 15.9448
# [6200]	training's rmse: 11.9988	valid_1's rmse: 15.9349
# [6300]	training's rmse: 11.9617	valid_1's rmse: 15.9206
# [6400]	training's rmse: 11.9286	valid_1's rmse: 15.9081
# [6500]	training's rmse: 11.8959	valid_1's rmse: 15.8949
# [6600]	training's rmse: 11.866	valid_1's rmse: 15.8826
# [6700]	training's rmse: 11.8361	valid_1's rmse: 15.8711
# [6800]	training's rmse: 11.8057	valid_1's rmse: 15.8599
# [6900]	training's rmse: 11.7703	valid_1's rmse: 15.844
# [7000]	training's rmse: 11.737	valid_1's rmse: 15.8268
# [7100]	training's rmse: 11.7074	valid_1's rmse: 15.816
# [7200]	training's rmse: 11.6793	valid_1's rmse: 15.8081
# [7300]	training's rmse: 11.6509	valid_1's rmse: 15.7969
# [7400]	training's rmse: 11.6181	valid_1's rmse: 15.7944
# [7500]	training's rmse: 11.5939	valid_1's rmse: 15.7856
# [7600]	training's rmse: 11.569	valid_1's rmse: 15.772
# [7700]	training's rmse: 11.543	valid_1's rmse: 15.7614
# [7800]	training's rmse: 11.519	valid_1's rmse: 15.7483
# [7900]	training's rmse: 11.4932	valid_1's rmse: 15.7382
# [8000]	training's rmse: 11.469	valid_1's rmse: 15.7299
# [8100]	training's rmse: 11.4452	valid_1's rmse: 15.7246
# [8200]	training's rmse: 11.42	valid_1's rmse: 15.7187
# [8300]	training's rmse: 11.3954	valid_1's rmse: 15.7079
# [8400]	training's rmse: 11.3693	valid_1's rmse: 15.6985
# [8500]	training's rmse: 11.3454	valid_1's rmse: 15.6837
# [8600]	training's rmse: 11.3215	valid_1's rmse: 15.6789
# [8700]	training's rmse: 11.2982	valid_1's rmse: 15.673
# [8800]	training's rmse: 11.273	valid_1's rmse: 15.6699
# [8900]	training's rmse: 11.2478	valid_1's rmse: 15.6575
# [9000]	training's rmse: 11.2256	valid_1's rmse: 15.6512
# [9100]	training's rmse: 11.2022	valid_1's rmse: 15.6388
# [9200]	training's rmse: 11.1819	valid_1's rmse: 15.6345
# [9300]	training's rmse: 11.1602	valid_1's rmse: 15.6291
# [9400]	training's rmse: 11.1402	valid_1's rmse: 15.6256
# [9500]	training's rmse: 11.1194	valid_1's rmse: 15.6152
# [9600]	training's rmse: 11.0984	valid_1's rmse: 15.6064
# [9700]	training's rmse: 11.0749	valid_1's rmse: 15.5986
# [9800]	training's rmse: 11.0517	valid_1's rmse: 15.5936
# [9900]	training's rmse: 11.0309	valid_1's rmse: 15.5827
# [10000]	training's rmse: 11.0108	valid_1's rmse: 15.5788
# [10100]	training's rmse: 10.99	valid_1's rmse: 15.5785
# [10200]	training's rmse: 10.9703	valid_1's rmse: 15.5699
# [10300]	training's rmse: 10.9458	valid_1's rmse: 15.5626
# [10400]	training's rmse: 10.9235	valid_1's rmse: 15.5577
# [10500]	training's rmse: 10.9043	valid_1's rmse: 15.5513
# [10600]	training's rmse: 10.8851	valid_1's rmse: 15.5448
# [10700]	training's rmse: 10.8661	valid_1's rmse: 15.5394
# [10800]	training's rmse: 10.8494	valid_1's rmse: 15.5362
# [10900]	training's rmse: 10.83	valid_1's rmse: 15.5307
# [11000]	training's rmse: 10.8105	valid_1's rmse: 15.5251
# [11100]	training's rmse: 10.7946	valid_1's rmse: 15.5268
# [11200]	training's rmse: 10.7729	valid_1's rmse: 15.5105
# [11300]	training's rmse: 10.7494	valid_1's rmse: 15.5101
# [11400]	training's rmse: 10.7305	valid_1's rmse: 15.5059
# [11500]	training's rmse: 10.7122	valid_1's rmse: 15.5027
# [11600]	training's rmse: 10.6914	valid_1's rmse: 15.4926
# [11700]	training's rmse: 10.6717	valid_1's rmse: 15.4889
# [11800]	training's rmse: 10.6518	valid_1's rmse: 15.4836
# [11900]	training's rmse: 10.6345	valid_1's rmse: 15.4794
# [12000]	training's rmse: 10.6167	valid_1's rmse: 15.4773
# [12100]	training's rmse: 10.5986	valid_1's rmse: 15.475
# [12200]	training's rmse: 10.5806	valid_1's rmse: 15.468
# [12300]	training's rmse: 10.567	valid_1's rmse: 15.4608
# [12400]	training's rmse: 10.5486	valid_1's rmse: 15.4583
# [12500]	training's rmse: 10.5293	valid_1's rmse: 15.453
# [12600]	training's rmse: 10.5115	valid_1's rmse: 15.444
# [12700]	training's rmse: 10.4955	valid_1's rmse: 15.4333
# [12800]	training's rmse: 10.4807	valid_1's rmse: 15.428
# [12900]	training's rmse: 10.4657	valid_1's rmse: 15.4247
# [13000]	training's rmse: 10.4482	valid_1's rmse: 15.4146
# [13100]	training's rmse: 10.4326	valid_1's rmse: 15.4089
# [13200]	training's rmse: 10.4181	valid_1's rmse: 15.4084
# [13300]	training's rmse: 10.4043	valid_1's rmse: 15.4049
# [13400]	training's rmse: 10.3871	valid_1's rmse: 15.3932
# [13500]	training's rmse: 10.3704	valid_1's rmse: 15.3816
# [13600]	training's rmse: 10.3562	valid_1's rmse: 15.3751
# [13700]	training's rmse: 10.3427	valid_1's rmse: 15.3713
# [13800]	training's rmse: 10.3261	valid_1's rmse: 15.368
# [13900]	training's rmse: 10.31	valid_1's rmse: 15.3683
# [14000]	training's rmse: 10.2942	valid_1's rmse: 15.3677
# Early stopping, best iteration is:
# [13865]	training's rmse: 10.3155	valid_1's rmse: 15.3634
# Fold  4 RMSE : 15.363372
#
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 20.5827	valid_1's rmse: 20.6595
# [200]	training's rmse: 19.1724	valid_1's rmse: 19.4116
# [300]	training's rmse: 18.3467	valid_1's rmse: 18.6787
# [400]	training's rmse: 17.74	valid_1's rmse: 18.1991
# [500]	training's rmse: 17.2991	valid_1's rmse: 17.8657
# [600]	training's rmse: 16.9398	valid_1's rmse: 17.5774
# [700]	training's rmse: 16.6225	valid_1's rmse: 17.3625
# [800]	training's rmse: 16.3392	valid_1's rmse: 17.153
# [900]	training's rmse: 16.0959	valid_1's rmse: 16.9939
# [1000]	training's rmse: 15.8714	valid_1's rmse: 16.8237
# [1100]	training's rmse: 15.6818	valid_1's rmse: 16.7242
# [1200]	training's rmse: 15.4928	valid_1's rmse: 16.5879
# [1300]	training's rmse: 15.3263	valid_1's rmse: 16.4699
# [1400]	training's rmse: 15.195	valid_1's rmse: 16.4034
# [1500]	training's rmse: 15.0478	valid_1's rmse: 16.3122
# [1600]	training's rmse: 14.9243	valid_1's rmse: 16.2587
# [1700]	training's rmse: 14.7996	valid_1's rmse: 16.1934
# [1800]	training's rmse: 14.6723	valid_1's rmse: 16.1141
# [1900]	training's rmse: 14.5565	valid_1's rmse: 16.0601
# [2000]	training's rmse: 14.4619	valid_1's rmse: 16.0125
# [2100]	training's rmse: 14.3616	valid_1's rmse: 15.9453
# [2200]	training's rmse: 14.2646	valid_1's rmse: 15.8989
# [2300]	training's rmse: 14.167	valid_1's rmse: 15.8603
# [2400]	training's rmse: 14.0794	valid_1's rmse: 15.8001
# [2500]	training's rmse: 13.9926	valid_1's rmse: 15.7598
# [2600]	training's rmse: 13.8992	valid_1's rmse: 15.7028
# [2700]	training's rmse: 13.8289	valid_1's rmse: 15.6805
# [2800]	training's rmse: 13.7564	valid_1's rmse: 15.6517
# [2900]	training's rmse: 13.6829	valid_1's rmse: 15.6181
# [3000]	training's rmse: 13.6172	valid_1's rmse: 15.5796
# [3100]	training's rmse: 13.554	valid_1's rmse: 15.5332
# [3200]	training's rmse: 13.4897	valid_1's rmse: 15.4997
# [3300]	training's rmse: 13.426	valid_1's rmse: 15.4691
# [3400]	training's rmse: 13.3643	valid_1's rmse: 15.4404
# [3500]	training's rmse: 13.3051	valid_1's rmse: 15.3962
# [3600]	training's rmse: 13.2492	valid_1's rmse: 15.3593
# [3700]	training's rmse: 13.1936	valid_1's rmse: 15.3505
# [3800]	training's rmse: 13.1392	valid_1's rmse: 15.3272
# [3900]	training's rmse: 13.0836	valid_1's rmse: 15.3144
# [4000]	training's rmse: 13.0345	valid_1's rmse: 15.286
# [4100]	training's rmse: 12.98	valid_1's rmse: 15.275
# [4200]	training's rmse: 12.9305	valid_1's rmse: 15.2539
# [4300]	training's rmse: 12.8862	valid_1's rmse: 15.2382
# [4400]	training's rmse: 12.8424	valid_1's rmse: 15.2168
# [4500]	training's rmse: 12.7948	valid_1's rmse: 15.1968
# [4600]	training's rmse: 12.7509	valid_1's rmse: 15.183
# [4700]	training's rmse: 12.7103	valid_1's rmse: 15.1715
# [4800]	training's rmse: 12.6682	valid_1's rmse: 15.1608
# [4900]	training's rmse: 12.6288	valid_1's rmse: 15.1431
# [5000]	training's rmse: 12.5849	valid_1's rmse: 15.1239
# [5100]	training's rmse: 12.5402	valid_1's rmse: 15.0991
# [5200]	training's rmse: 12.5022	valid_1's rmse: 15.0793
# [5300]	training's rmse: 12.467	valid_1's rmse: 15.0649
# [5400]	training's rmse: 12.4258	valid_1's rmse: 15.0577
# [5500]	training's rmse: 12.3891	valid_1's rmse: 15.0391
# [5600]	training's rmse: 12.3472	valid_1's rmse: 15.0228
# [5700]	training's rmse: 12.31	valid_1's rmse: 15.0087
# [5800]	training's rmse: 12.2741	valid_1's rmse: 14.9958
# [5900]	training's rmse: 12.2389	valid_1's rmse: 14.994
# [6000]	training's rmse: 12.2078	valid_1's rmse: 14.9762
# [6100]	training's rmse: 12.171	valid_1's rmse: 14.9559
# [6200]	training's rmse: 12.1316	valid_1's rmse: 14.9455
# [6300]	training's rmse: 12.0997	valid_1's rmse: 14.93
# [6400]	training's rmse: 12.0637	valid_1's rmse: 14.9173
# [6500]	training's rmse: 12.0262	valid_1's rmse: 14.9005
# [6600]	training's rmse: 11.9941	valid_1's rmse: 14.8864
# [6700]	training's rmse: 11.9627	valid_1's rmse: 14.8768
# [6800]	training's rmse: 11.9295	valid_1's rmse: 14.8584
# [6900]	training's rmse: 11.8902	valid_1's rmse: 14.8413
# [7000]	training's rmse: 11.8567	valid_1's rmse: 14.8285
# [7100]	training's rmse: 11.8266	valid_1's rmse: 14.8251
# [7200]	training's rmse: 11.7985	valid_1's rmse: 14.8177
# [7300]	training's rmse: 11.7746	valid_1's rmse: 14.8118
# [7400]	training's rmse: 11.7466	valid_1's rmse: 14.8098
# [7500]	training's rmse: 11.7193	valid_1's rmse: 14.8058
# [7600]	training's rmse: 11.6884	valid_1's rmse: 14.7966
# [7700]	training's rmse: 11.6556	valid_1's rmse: 14.7875
# [7800]	training's rmse: 11.6232	valid_1's rmse: 14.7829
# [7900]	training's rmse: 11.5922	valid_1's rmse: 14.7685
# [8000]	training's rmse: 11.5649	valid_1's rmse: 14.7626
# [8100]	training's rmse: 11.5385	valid_1's rmse: 14.767
# [8200]	training's rmse: 11.5103	valid_1's rmse: 14.7594
# [8300]	training's rmse: 11.4863	valid_1's rmse: 14.7578
# [8400]	training's rmse: 11.458	valid_1's rmse: 14.7519
# [8500]	training's rmse: 11.431	valid_1's rmse: 14.749
# [8600]	training's rmse: 11.4038	valid_1's rmse: 14.7406
# [8700]	training's rmse: 11.3778	valid_1's rmse: 14.7344
# [8800]	training's rmse: 11.349	valid_1's rmse: 14.7236
# [8900]	training's rmse: 11.3226	valid_1's rmse: 14.7244
# [9000]	training's rmse: 11.3009	valid_1's rmse: 14.7176
# [9100]	training's rmse: 11.277	valid_1's rmse: 14.711
# [9200]	training's rmse: 11.2515	valid_1's rmse: 14.7056
# [9300]	training's rmse: 11.228	valid_1's rmse: 14.6993
# [9400]	training's rmse: 11.2024	valid_1's rmse: 14.6957
# [9500]	training's rmse: 11.1814	valid_1's rmse: 14.69
# [9600]	training's rmse: 11.1562	valid_1's rmse: 14.6854
# [9700]	training's rmse: 11.1317	valid_1's rmse: 14.6806
# [9800]	training's rmse: 11.1094	valid_1's rmse: 14.6725
# [9900]	training's rmse: 11.0832	valid_1's rmse: 14.6609
# [10000]	training's rmse: 11.0609	valid_1's rmse: 14.6564
# [10100]	training's rmse: 11.0385	valid_1's rmse: 14.6565
# [10200]	training's rmse: 11.0155	valid_1's rmse: 14.6504
# [10300]	training's rmse: 10.9935	valid_1's rmse: 14.6479
# [10400]	training's rmse: 10.9722	valid_1's rmse: 14.6367
# [10500]	training's rmse: 10.9483	valid_1's rmse: 14.6312
# [10600]	training's rmse: 10.9272	valid_1's rmse: 14.6277
# [10700]	training's rmse: 10.9058	valid_1's rmse: 14.6201
# [10800]	training's rmse: 10.887	valid_1's rmse: 14.6129
# [10900]	training's rmse: 10.8669	valid_1's rmse: 14.6091
# [11000]	training's rmse: 10.846	valid_1's rmse: 14.6055
# [11100]	training's rmse: 10.8249	valid_1's rmse: 14.6101
# [11200]	training's rmse: 10.8044	valid_1's rmse: 14.6043
# Early stopping, best iteration is:
# [11051]	training's rmse: 10.8354	valid_1's rmse: 14.6028
# Fold  5 RMSE : 14.602765
#
# Full RMSE score 14.745171

# %%
df.loc[pred.index, 'hr_watch_rate'] = pred[['1001_fold_0', '1001_fold_1',
                                        '1001_fold_2', '1001_fold_3',
                                        '1001_fold_4']].mean(axis=1)

# %%
plt.plot(df['hr_watch_rate'])

# %%
df.to_csv('Crowdsignal_imputed_hr.csv', index=False)
